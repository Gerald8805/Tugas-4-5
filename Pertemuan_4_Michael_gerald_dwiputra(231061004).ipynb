# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/content/dqlab_training_task (1).csv')

# %%
df.head()
# Out:
#    Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0           0   52    1   0       125   212    0        1      168      0
# 1           1   53    1   0       140   203    1        0      155      1
# 2           2   70    1   0       145   174    0        1      125      1
# 3           3   61    1   0       148   203    0        1      161      0
# 4           4   62    0   0       138   294    1        1      106      0
#
#    oldpeak  slope  ca  thal  target
# 0      1.0      2   2     3       0
# 1      3.1      0   0     3       0
# 2      2.6      0   0     3       0
# 3      0.0      2   1     3       0
# 4      1.9      1   3     2       0

# %%
len(df)
# Out:
# 283

# %%
df.tail()
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 278         723   68    0   2       120   211    0        0      115      0
# 279         733   44    0   2       108   141    0        1      175      0
# 280         739   52    1   0       128   255    0        1      161      1
# 281         843   59    1   3       160   273    0        0      125      0
# 282         878   54    1   0       120   188    0        1      113      0
#
#      oldpeak  slope  ca  thal  target
# 278      1.5      1   0     2       1
# 279      0.6      1   0     2       1
# 280      0.0      2   1     3       0
# 281      0.0      2   0     2       0
# 282      1.4      1   1     3       0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  283 non-null    int64
#  1   age         283 non-null    int64
#  2   sex         283 non-null    int64
#  3   cp          283 non-null    int64
#  4   trestbps    283 non-null    int64
#  5   chol        283 non-null    int64
#  6   fbs         283 non-null    int64
#  7   restecg     283 non-null    int64
#  8   thalach     283 non-null    int64
#  9   exang       283 non-null    int64
#  10  oldpeak     283 non-null    float64
#  11  slope       283 non-null    int64
#  12  ca          283 non-null    int64
#  13  thal        283 non-null    int64
#  14  target      283 non-null    int64
# dtypes: float64(1), int64(14)
# memory usage: 33.3 KB
# None

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang         0
# oldpeak       0
# slope         0
# ca            0
# thal          0
# target        0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# Unnamed: 0    0.0
# age           0.0
# sex           0.0
# cp            0.0
# trestbps      0.0
# chol          0.0
# fbs           0.0
# restecg       0.0
# thalach       0.0
# exang         0.0
# oldpeak       0.0
# slope         0.0
# ca            0.0
# thal          0.0
# target        0.0
# dtype: float64

# %%
df.isna().any()
# Out:
# Unnamed: 0    False
# age           False
# sex           False
# cp            False
# trestbps      False
# chol          False
# fbs           False
# restecg       False
# thalach       False
# exang         False
# oldpeak       False
# slope         False
# ca            False
# thal          False
# target        False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  283 non-null    int64
#  1   age         283 non-null    int64
#  2   sex         283 non-null    int64
#  3   cp          283 non-null    int64
#  4   trestbps    283 non-null    int64
#  5   chol        283 non-null    int64
#  6   fbs         283 non-null    int64
#  7   restecg     283 non-null    int64
#  8   thalach     283 non-null    int64
#  9   exang       283 non-null    int64
#  10  oldpeak     283 non-null    float64
#  11  slope       283 non-null    int64
#  12  ca          283 non-null    int64
#  13  thal        283 non-null    int64
#  14  target      283 non-null    int64
# dtypes: float64(1), int64(14)
# memory usage: 33.3 KB

# %%
df['sex'].mean()
# Out:
# 0.6996466431095406

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].fillna(df['Unnamed: 0'].mean())
df['age'] = df['age'].fillna(df['age'].mean())
df['sex'] = df['sex'].fillna(df['sex'].mean())
df['trestbps'] = df['trestbps'].fillna(df['trestbps'].mean())
df['chol'] = df['chol'].fillna(df['chol'].mean())
df['fbs'] = df['fbs'].fillna(df['fbs'].mean())
df['restecg'] = df['restecg'].fillna(df['restecg'].mean())
df['thalach'] = df['thalach'].fillna(df['thalach'].mean())
df['exang'] = df['exang'].fillna(df['exang'].mean())
df['oldpeak'] = df['oldpeak'].fillna(df['oldpeak'].mean())
df['slope'] = df['slope'].fillna(df['slope'].mean())
df['ca'] = df['ca'].fillna(df['ca'].mean())
df['thal'] = df['thal'].fillna(df['thal'].mean())
df['target'] = df['target'].fillna(df['target'].mean())

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang         0
# oldpeak       0
# slope         0
# ca            0
# thal          0
# target        0
# dtype: int64

# %%
df['sex'].mean()
# Out:
# 0.6996466431095406

# %%
df = df.rename(columns={'age':'sex'})

# %%
df.head()
# Out:
#    Unnamed: 0  sex  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0           0   52    1   0       125   212    0        1      168      0
# 1           1   53    1   0       140   203    1        0      155      1
# 2           2   70    1   0       145   174    0        1      125      1
# 3           3   61    1   0       148   203    0        1      161      0
# 4           4   62    0   0       138   294    1        1      106      0
#
#    oldpeak  slope  ca  thal  target
# 0      1.0      2   2     3       0
# 1      3.1      0   0     3       0
# 2      2.6      0   0     3       0
# 3      0.0      2   1     3       0
# 4      1.9      1   3     2       0

# %%
df.describe()
# Out:
#        Unnamed: 0         age         sex          cp    trestbps        chol  \
# count  283.000000  283.000000  283.000000  283.000000  283.000000  283.000000
# mean   239.918728   54.049470    0.699647    0.985866  129.883392  242.314488
# std    190.411063    9.128186    0.459224    1.031324   15.387795   44.654188
# min      0.000000   29.000000    0.000000    0.000000   94.000000  126.000000
# 25%     88.500000   47.000000    0.000000    0.000000  120.000000  210.500000
# 50%    194.000000   55.000000    1.000000    1.000000  130.000000  239.000000
# 75%    348.500000   60.000000    1.000000    2.000000  140.000000  270.500000
# max    878.000000   77.000000    1.000000    3.000000  170.000000  360.000000
#
#               fbs     restecg     thalach       exang     oldpeak       slope  \
# count  283.000000  283.000000  283.000000  283.000000  283.000000  283.000000
# mean     0.141343    0.522968  149.961131    0.318021    0.951943    1.427562
# ...

# %%
import seaborn as sns
sns.boxplot(df['age'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='age'>

# %%
df['age'].min(), df['age'].max()
# Out:
# (29, 77)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df['age_minmax'] = MinMaxScaler().fit_transform(df[['cp']].values.reshape(len(df),1)) # Changed 'Age

# %%
df[df['age_minmax']== 1]
# Out:
#      Unnamed: 0  sex  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 31           36   51    1   3       125   213    0        0      125      1
# 43           50   58    0   3       150   283    1        0      162      0
# 47           56   56    1   3       120   193    0        0      162      0
# 54           65   59    1   3       170   288    0        0      159      0
# 83          104   52    1   3       118   186    0        0      190      0
# 98          125   60    0   3       150   240    0        1      171      0
# 107         142   61    1   3       134   234    0        1      145      0
# 108         143   34    1   3       118   182    0        0      174      0
# 113         148   52    1   3       152   298    1        1      178      0
# 117         156   40    1   3       140   199    0        1      178      1
# 132         181   64    1   3       110   211    0        0      144      1
# ...

# %%
sns.displot(df['trestbps'],kde='hist')

# %%
sns.displot(df['chol'],kde='hist')

# %%
import numpy as np
df['age'] = np.log(df['age'])
sns.displot(df['age'],kde= 'hist')

# %% [markdown]
# panjang,korelasi,normal/tidak,data hilang,heatmap

# %%
numeric_data = df.select_dtypes(include=[np.number]) # Changed 'data' to 'df'
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
X = df.iloc[:,1]
X.head(5)
# Out:
# 0    52
# 1    53
# 2    70
# 3    61
# 4    62
# Name: age, dtype: int64

# %%
y = df.iloc[:,5]
y.head(5)
# Out:
# 0    212
# 1    203
# 2    174
# 3    203
# 4    294
# Name: chol, dtype: int64

# %%
plt.scatter(X,y)
plt.title('age vs chol')
plt.xlabel('age')
plt.ylabel('chol')
# Out:
# Text(0, 0.5, 'chol')
